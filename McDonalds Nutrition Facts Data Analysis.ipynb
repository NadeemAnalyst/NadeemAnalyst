# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %%
mcd_df = pd.read_csv("menu.csv")

# %%
mcd_df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
#lets find out the null values
mcd_df.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
mcd_df.describe().T
# Out:
#                                count        mean         std  min      25%  \
# Calories                       260.0  368.269231  240.269886  0.0  210.000
# Calories from Fat              260.0  127.096154  127.875914  0.0   20.000
# Total Fat                      260.0   14.165385   14.205998  0.0    2.375
# Total Fat (% Daily Value)      260.0   21.815385   21.885199  0.0    3.750
# Saturated Fat                  260.0    6.007692    5.321873  0.0    1.000
# Saturated Fat (% Daily Value)  260.0   29.965385   26.639209  0.0    4.750
# Trans Fat                      260.0    0.203846    0.429133  0.0    0.000
# Cholesterol                    260.0   54.942308   87.269257  0.0    5.000
# Cholesterol (% Daily Value)    260.0   18.392308   29.091653  0.0    2.000
# Sodium                         260.0  495.750000  577.026323  0.0  107.500
# Sodium (% Daily Value)         260.0   20.676923   24.034954  0.0    4.750
# ...

# %%
mcd_df.shape
# Out:
# (260, 24)

# %%
mcd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
#Lets find out Items present in each Category
mcd_df['Category'].value_counts()
#.value_counts() is used to count the values in a column
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
mcd_df['Category'].nunique()
# Out:
# 9

# %%
mcd_df['Item'].value_counts()
# Out:
# Egg McMuffin                                        1
# Nonfat Latte (Small)                                1
# Nonfat Latte (Large)                                1
# Nonfat Caramel Latte (Small)                        1
# Nonfat Caramel Latte (Medium)                       1
#                                                    ..
# Chipotle BBQ Snack Wrap (Grilled Chicken)           1
# Honey Mustard Snack Wrap (Crispy Chicken)           1
# Honey Mustard Snack Wrap (Grilled Chicken)          1
# Ranch Snack Wrap (Crispy Chicken)                   1
# McFlurry with Reese's Peanut Butter Cups (Snack)    1
# Name: Item, Length: 260, dtype: int64

# %%
mcd_df['Item'].nunique()
# Out:
# 260

# %%
plt.figure(figsize=(16,8))
mcd_df['Category'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=mcd_df[['Calories','Calories from Fat','Total Fat','Saturated Fat']])
# Out:
# <AxesSubplot:>

# %%
correlation = mcd_df.corr()
correlation
# Out:
#                                Calories  Calories from Fat  Total Fat  \
# Calories                       1.000000           0.904588   0.904409
# Calories from Fat              0.904588           1.000000   0.999663
# Total Fat                      0.904409           0.999663   1.000000
# Total Fat (% Daily Value)      0.904123           0.999725   0.999765
# Saturated Fat                  0.845564           0.847008   0.846707
# Saturated Fat (% Daily Value)  0.847631           0.849592   0.849293
# Trans Fat                      0.522441           0.433686   0.431453
# Cholesterol                    0.596399           0.682161   0.680547
# Cholesterol (% Daily Value)    0.595208           0.681607   0.680000
# Sodium                         0.712309           0.846624   0.846158
# Sodium (% Daily Value)         0.713415           0.847276   0.846780
# Carbohydrates                  0.781539           0.461672   0.461213
# ...

# %%
plt.figure(figsize=(16,8))
sns.heatmap(correlation,annot=True)
# Out:
# <AxesSubplot:>

# %%
mcd_df['Category'].nunique()
# Out:
# 9

# %%
mcd_df['Category'].unique()    
from pandas import DataFrame
category_list = sorted(mcd_df['Category'].unique())
type(sorted(mcd_df['Category'].unique()))
a = pd.DataFrame(category_list,columns=[''])
a.index += 1
print(a)
# Out:
#
# 1         Beef & Pork
# 2           Beverages
# 3           Breakfast
# 4      Chicken & Fish
# 5        Coffee & Tea
# 6            Desserts
# 7              Salads
# 8  Smoothies & Shakes
# 9      Snacks & Sides

# %%
b = pd.pivot_table(mcd_df, 'Cholesterol (% Daily Value)', index=['Category'])
Result = b.sort_values('Cholesterol (% Daily Value)', ascending=False)
Result
# Out:
#                     Cholesterol (% Daily Value)
# Category
# Breakfast                             50.952381
# Beef & Pork                           28.933333
# Chicken & Fish                        25.222222
# Salads                                17.333333
# Smoothies & Shakes                    14.714286
# Coffee & Tea                           9.378947
# Snacks & Sides                         6.230769
# Desserts                               4.857143
# Beverages                              0.185185

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=b, x='Category',y ='Cholesterol (% Daily Value)')
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Cholesterol (% Daily Value)'>

# %%
mcd_df['Item'].head(16)
# Out:
# 0                                          Egg McMuffin
# 1                                     Egg White Delight
# 2                                      Sausage McMuffin
# 3                             Sausage McMuffin with Egg
# 4                      Sausage McMuffin with Egg Whites
# 5                                  Steak & Egg McMuffin
# 6         Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7           Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8     Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9     Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 10                    Sausage Biscuit (Regular Biscuit)
# 11                      Sausage Biscuit (Large Biscuit)
# 12           Sausage Biscuit with Egg (Regular Biscuit)
# 13             Sausage Biscuit with Egg (Large Biscuit)
# 14    Sausage Biscuit with Egg Whites (Regular Biscuit)
# 15      Sausage Biscuit with Egg Whites (Large Biscuit)
# Name: Item, dtype: object

# %%
c = pd.pivot_table(mcd_df, 'Sodium', index=['Item'])
Result= c.sort_values('Sodium', ascending=False).head(15)
Result
# Out:
#                                                     Sodium
# Item
# Chicken McNuggets (40 piece)                          3600
# Big Breakfast with Hotcakes and Egg Whites (Lar...    2290
# Big Breakfast with Hotcakes (Large Biscuit)           2260
# Big Breakfast with Hotcakes and Egg Whites (Reg...    2170
# Big Breakfast with Hotcakes (Regular Biscuit)         2150
# Chicken McNuggets (20 piece)                          1800
# Bacon Clubhouse Crispy Chicken Sandwich               1720
# Big Breakfast with Egg Whites (Large Biscuit)         1700
# Big Breakfast (Large Biscuit)                         1680
# Big Breakfast with Egg Whites (Regular Biscuit)       1590
# Bacon Clubhouse Grilled Chicken Sandwich              1560
# Big Breakfast (Regular Biscuit)                       1560
# Premium McWrap Chicken & Bacon (Crispy Chicken)       1540
# Steak, Egg & Cheese Bagel                             1510
# Bacon, Egg & Cheese Bagel with Egg Whites             1480

# %%
d = pd.pivot_table(mcd_df, 'Saturated Fat', index=['Item'])
Result= d.sort_values('Saturated Fat', ascending=False).head(15)
Result
# Out:
#                                                     Saturated Fat
# Item
# McFlurry with M&M’s Candies (Medium)                         20.0
# Big Breakfast with Hotcakes (Large Biscuit)                  20.0
# Chicken McNuggets (40 piece)                                 20.0
# Frappé Chocolate Chip (Large)                                20.0
# Double Quarter Pounder with Cheese                           19.0
# Big Breakfast with Hotcakes (Regular Biscuit)                19.0
# Big Breakfast (Large Biscuit)                                18.0
# Frappé Mocha (Large)                                         17.0
# Frappé Chocolate Chip (Medium)                               17.0
# Big Breakfast (Regular Biscuit)                              17.0
# Frappé Caramel (Large)                                       17.0
# Big Breakfast with Hotcakes and Egg Whites (Reg...           16.0
# Big Breakfast with Hotcakes and Egg Whites (Lar...           16.0
# ...

# %%
c = pd.pivot_table(mcd_df, 'Carbohydrates', index=['Category'])
Result= c.sort_values('Carbohydrates', ascending=False)
Result
# Out:
#                     Carbohydrates
# Category
# Smoothies & Shakes      90.428571
# Breakfast               49.761905
# Chicken & Fish          49.074074
# Coffee & Tea            44.526316
# Beef & Pork             40.133333
# Desserts                34.857143
# Snacks & Sides          29.153846
# Beverages               28.814815
# Salads                  21.666667

# %%
e = pd.pivot_table(mcd_df, 'Sugars', index=['Category'])
Result= e.sort_values('Sugars', ascending=False)
Result
# Out:
#                        Sugars
# Category
# Smoothies & Shakes  77.892857
# Coffee & Tea        39.610526
# Beverages           27.851852
# Desserts            26.142857
# Beef & Pork          8.800000
# Breakfast            8.261905
# Chicken & Fish       7.333333
# Salads               6.833333
# Snacks & Sides       4.076923

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=e,x='Category',y='Sugars')
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Sugars'>

# %%
f = pd.pivot_table(mcd_df, 'Calcium (% Daily Value)',index=['Item'])
Result= f.sort_values('Calcium (% Daily Value)', ascending=False)
Result.head(15)
# Out:
#                                                     Calcium (% Daily Value)
# Item
# Strawberry Shake (Large)                                                 70
# McFlurry with M&M’s Candies (Medium)                                     70
# Shamrock Shake (Large)                                                   60
# McFlurry with Reese's Peanut Butter Cups (Medium)                        60
# Vanilla Shake (Large)                                                    60
# Hot Chocolate with Nonfat Milk (Large)                                   60
# Hot Chocolate (Large)                                                    60
# Chocolate Shake (Large)                                                  60
# Chocolate Shake (Medium)                                                 50
# Latte with Sugar Free French Vanilla Syrup (Large)                       50
# Nonfat French Vanilla Latte (Large)                                      50
# ...
